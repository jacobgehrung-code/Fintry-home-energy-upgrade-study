# %%
# STEP 2: Import Required Libraries
# --------------------------------
import pandas as pd

# %%
# STEP 3: Define File Paths
# ------------------------
epc_file_path = "/Users/jakegehrung/Desktop/data_raw/data_processed/fintry_epc_windows_upgrade_types.csv"
hp_cost_file_path = "/Users/jakegehrung/Desktop/data_raw/REFERENCE FILES/hp_cap_cost.csv"

# %%
# STEP 4: Load the Datasets
# -------------------------
epc_df = pd.read_csv(epc_file_path)
hp_cost_df = pd.read_csv(hp_cost_file_path)

# Preview to verify loading (optional)
print(epc_df.head())
print(hp_cost_df.head())
# Out:
#    BUILDING_REFERENCE_NUMBER  OSG_REFERENCE_NUMBER              ADDRESS1  \
# 0                 1001829067           122009933.0  19 CULCREUCH AVENUE
# 1                 1001951858           122010025.0             GLENVIEW
# 2                 1001829071           122009868.0  22 CULCREUCH AVENUE
# 3                 1234761001           122009968.0    1 MENZIES TERRACE
# 4                 1001991633           122009892.0       50 MAIN STREET
#
#   ADDRESS2  ADDRESS3 POSTCODE  LATITUDE  LONGITUDE  ORIENTATION  \
# 0  FINTRY   GLASGOW   G63 0YB   56.0557    -4.2233          100
# 1  FINTRY   GLASGOW   G63 0XJ   56.0528    -4.2206          180
# 2  FINTRY   GLASGOW   G63 0YB   56.0555    -4.2237          100
# 3  FINTRY   GLASGOW   G63 0YJ   56.0584    -4.2248          150
# 4  FINTRY   GLASGOW   G63 0XF   56.0547    -4.2283          150
#
#    ORIENTATION_ESPR_ROT  ... BATTERY_NPV_FLEX WINDOWS_IRR_FLEX ROOF_IRR_FLEX  \
# ...

# %%
# STEP 5 (FINAL FIX): Correctly Read Single-Value CSV
# --------------------------------------------------
# Your file is being interpreted as a HEADER (column name) instead of data.
# So we extract the value from the column name instead.

# Reload normally (as you already did)
hp_cost_df = pd.read_csv(hp_cost_file_path)

# Extract value from column name
hp_value = hp_cost_df.columns[0]

# Convert to numeric (recommended)
hp_value = float(hp_value)

print("Extracted HP Cap Cost:", hp_value)
# Out:
# Extracted HP Cap Cost: 7000.0

# %%
# STEP 6: Create or Replace Column in EPC Dataset
# ----------------------------------------------
epc_df["HP_CAP_COST"] = hp_value

print(epc_df[["HP_CAP_COST"]].head())
# Out:
#    HP_CAP_COST
# 0       7000.0
# 1       7000.0
# 2       7000.0
# 3       7000.0
# 4       7000.0

# %%
# STEP 7: Save Updated Dataset
# ----------------------------
output_path = "/Users/jakegehrung/Desktop/data_raw/data_processed/fintry_epc_hp_cap_cost.csv"
epc_df.to_csv(output_path, index=False)

print("Updated file saved to:", output_path)
# Out:
# Updated file saved to: /Users/jakegehrung/Desktop/data_raw/data_processed/fintry_epc_hp_cap_cost.csv
