# %%
# STEP 1 — Import Libraries
# ------------------------------------------------
# Import required modules for notebook execution

import papermill as pm
import os

# %%
# STEP 2 — Define Base Directory
# ------------------------------------------------
# Set the directory where all notebooks are stored

BASE_DIR = "/Users/jakegehrung/Desktop/data_raw/notebooks/Python_Modeling"

# %%
# STEP 3 — Define Execution Order
# ------------------------------------------------
# List notebooks in the exact order required

notebooks = [
    "54-copy_elec_results_to_tot.ipynb",
    "55-copy_lpg_results_to_tot.ipynb",
    "56-copy_min_wood_results_to_tot.ipynb",
    "57-copy_mains_gas_results_to_tot.ipynb",
    "58-copy_oil_results_to_tot.ipynb",
    "59-copy_wood_logs_results_to_tot.ipynb",
    "60-copy_wood_pellets_results_to_tot.ipynb",
    "61-copy_wood_chips_to_tot.ipynb",
    "62-copy_coal_to_tot.ipynb"
]

# %%
# STEP 4 — Define Output Directory (Optional but Recommended)
# ------------------------------------------------
# This stores executed notebooks for debugging and traceability

OUTPUT_DIR = os.path.join(BASE_DIR, "executed_notebooks")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# STEP 5 — Execute Notebooks Sequentially
# ------------------------------------------------
# Runs each notebook in order and stops if an error occurs

for i, nb in enumerate(notebooks, start=1):
    input_path = os.path.join(BASE_DIR, nb)
    output_path = os.path.join(OUTPUT_DIR, f"executed_{nb}")
    
    print(f"\nRunning Step {i}: {nb}")
    
    try:
        pm.execute_notebook(
            input_path=input_path,
            output_path=output_path
        )
        print(f"Completed Step {i}: {nb}")
        
    except Exception as e:
        print(f"Error in Step {i}: {nb}")
        print(str(e))
        break
# Out:
# Running Step 1: 54-copy_elec_results_to_tot.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Completed Step 1: 54-copy_elec_results_to_tot.ipynb
#
# Running Step 2: 55-copy_lpg_results_to_tot.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Completed Step 2: 55-copy_lpg_results_to_tot.ipynb
#
# Running Step 3: 56-copy_min_wood_results_to_tot.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Completed Step 3: 56-copy_min_wood_results_to_tot.ipynb
#
# Running Step 4: 57-copy_mains_gas_results_to_tot.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Completed Step 4: 57-copy_mains_gas_results_to_tot.ipynb
#
# Running Step 5: 58-copy_oil_results_to_tot.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Completed Step 5: 58-copy_oil_results_to_tot.ipynb
#
# Running Step 6: 59-copy_wood_logs_results_to_tot.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Completed Step 6: 59-copy_wood_logs_results_to_tot.ipynb
#
# Running Step 7: 60-copy_wood_pellets_results_to_tot.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Completed Step 7: 60-copy_wood_pellets_results_to_tot.ipynb
#
# Running Step 8: 61-copy_wood_chips_to_tot.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Completed Step 8: 61-copy_wood_chips_to_tot.ipynb
#
# Running Step 9: 62-copy_coal_to_tot.ipynb
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# Completed Step 9: 62-copy_coal_to_tot.ipynb

# %%
# STEP 6 — Completion Message
# ------------------------------------------------
# Confirms pipeline completion

print("\nPipeline execution finished.")
# Out:
# Pipeline execution finished.
