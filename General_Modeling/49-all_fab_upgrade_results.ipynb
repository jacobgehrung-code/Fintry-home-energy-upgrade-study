# %%
# STEP 1 — Import Libraries
# ------------------------------------------------
# Import required modules for notebook execution

import papermill as pm
import os

# %%
# STEP 2 — Define Base Directory
# ------------------------------------------------
# Set the directory where all notebooks are stored

BASE_DIR = "/Users/jakegehrung/Desktop/data_raw/notebooks/Python_Modeling"

# %%
# STEP 3 — Define Execution Order
# ------------------------------------------------
# List notebooks in the exact order required

notebooks = [
    "44-copy_fab_heat_results.ipynb",
    "45-copy_roof_heat_results.ipynb",
    "46-copy_walls_heat_results.ipynb",
    "47-copy_windows_heat_results.ipynb",
    "36-tot2.ipynb",
    "36-1_exp2.ipynb",
    "37-tot3.ipynb",
    "37-1_exp3.ipynb",
    "38-tot4.ipynb",
    "38-1_exp4.ipynb",
    "39-tot5.ipynb",
    "39-1_exp5.ipynb"
]

# %%
# STEP 4 — Define Output Directory (Optional but Recommended)
# ------------------------------------------------
# This stores executed notebooks for debugging and traceability

OUTPUT_DIR = os.path.join(BASE_DIR, "executed_notebooks")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# STEP 5 — Execute Notebooks Sequentially
# ------------------------------------------------
# Runs each notebook in order and stops if an error occurs

for i, nb in enumerate(notebooks, start=1):
    input_path = os.path.join(BASE_DIR, nb)
    output_path = os.path.join(OUTPUT_DIR, f"executed_{nb}")
    
    print(f"\nRunning Step {i}: {nb}")
    
    try:
        pm.execute_notebook(
            input_path=input_path,
            output_path=output_path
        )
        print(f"Completed Step {i}: {nb}")
        
    except Exception as e:
        print(f"Error in Step {i}: {nb}")
        print(str(e))
        break
# Out:
# Running Step 1: 44-copy_fab_heat_results.ipynb
# Executing:   0%|          | 0/10 [00:00<?, ?cell/s]
# Completed Step 1: 44-copy_fab_heat_results.ipynb
#
# Running Step 2: 45-copy_roof_heat_results.ipynb
# Executing:   0%|          | 0/10 [00:00<?, ?cell/s]
# Completed Step 2: 45-copy_roof_heat_results.ipynb
#
# Running Step 3: 46-copy_walls_heat_results.ipynb
# Executing:   0%|          | 0/10 [00:00<?, ?cell/s]
# Completed Step 3: 46-copy_walls_heat_results.ipynb
#
# Running Step 4: 47-copy_windows_heat_results.ipynb
# Executing:   0%|          | 0/10 [00:00<?, ?cell/s]
# Completed Step 4: 47-copy_windows_heat_results.ipynb
#
# Running Step 5: 36-tot2.ipynb
# Executing:   0%|          | 0/11 [00:00<?, ?cell/s]
# Completed Step 5: 36-tot2.ipynb
#
# Running Step 6: 37-tot3.ipynb
# Executing:   0%|          | 0/11 [00:00<?, ?cell/s]
# Completed Step 6: 37-tot3.ipynb
#
# Running Step 7: 38-tot4.ipynb
# Executing:   0%|          | 0/11 [00:00<?, ?cell/s]
# Completed Step 7: 38-tot4.ipynb
#
# Running Step 8: 39-tot5.ipynb
# Executing:   0%|          | 0/11 [00:00<?, ?cell/s]
# Completed Step 8: 39-tot5.ipynb

# %%
# STEP 6 — Completion Message
# ------------------------------------------------
# Confirms pipeline completion

print("\nPipeline execution finished.")
# Out:
# Pipeline execution finished.
