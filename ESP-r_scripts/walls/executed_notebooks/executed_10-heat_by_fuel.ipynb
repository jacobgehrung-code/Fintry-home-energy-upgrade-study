# %%
# STEP 1: Import libraries and define file paths
# Description: Set up required libraries and define key directory/file paths

import os
import pandas as pd

# File paths
epc_file = "/Users/jakegehrung/Desktop/data_raw/data_processed/fintry_epc_with_fuel_codes.csv"
models_base_path = "/Users/jakegehrung/Desktop/data_raw/baseline_models"

# Fuel columns (must match exactly your specification)
fuel_types = [
    "electricity",
    "lpg",
    "mineral_wood",
    "mains_gas",
    "oil",
    "wood_logs",
    "wood_pellets",
    "wood_chips",
    "coal"
]

# %%
# STEP 2: Load EPC dataset
# Description: Read EPC data and ensure correct columns exist

epc_df = pd.read_csv(epc_file)

required_columns = ["BUILDING_REFERENCE_NUMBER", "MAIN_FUEL_CODE", "SECOND_FUEL_CODE"]

for col in required_columns:
    if col not in epc_df.columns:
        raise ValueError(f"Missing required column: {col}")

# Ensure fuel codes are lowercase for consistency
epc_df["MAIN_FUEL_CODE"] = epc_df["MAIN_FUEL_CODE"].str.lower()
epc_df["SECOND_FUEL_CODE"] = epc_df["SECOND_FUEL_CODE"].str.lower()

# %%
# STEP 3: Iterate through buildings and process heat_load_dis.csv
# Description: Loop through each building, check for file existence, and generate heat_by_fuel.csv

for _, row in epc_df.iterrows():
    building_id = str(row["BUILDING_REFERENCE_NUMBER"])
    main_fuel = row["MAIN_FUEL_CODE"]
    second_fuel = row["SECOND_FUEL_CODE"]

    heating_folder = os.path.join(models_base_path, building_id, "HEATING")
    input_file = os.path.join(heating_folder, "heat_load_dis_walls.csv")
    output_file = os.path.join(heating_folder, "heat_by_fuel_walls.csv")

    # Skip if heat_load_dis.csv does not exist
    if not os.path.exists(input_file):
        print(f"Skipping {building_id}: heat_load_dis_walls.csv not found")
        continue

    try:
        heat_df = pd.read_csv(input_file)
    except Exception as e:
        print(f"Error reading {building_id}: {e}")
        continue

    # Validate required columns in heat_load_dis.csv
    required_heat_cols = ["Time", "secondary_heat_power", "main_heat_power"]
    for col in required_heat_cols:
        if col not in heat_df.columns:
            print(f"Skipping {building_id}: missing column {col}")
            continue

    # Create output dataframe with Time column
    output_df = pd.DataFrame()
    output_df["Time"] = heat_df["Time"]

    # Initialize all fuel columns with zeros
    for fuel in fuel_types:
        output_df[fuel] = 0.0

    # Add main heat power to correct fuel column
    if main_fuel in fuel_types:
        output_df[main_fuel] += heat_df["main_heat_power"]
    else:
        print(f"Warning: Unknown MAIN_FUEL_CODE '{main_fuel}' for {building_id}")

    # Add secondary heat power to correct fuel column
    if second_fuel in fuel_types:
        output_df[second_fuel] += heat_df["secondary_heat_power"]
    else:
        print(f"Warning: Unknown SECOND_FUEL_CODE '{second_fuel}' for {building_id}")

    # Save output CSV
    try:
        output_df.to_csv(output_file, index=False)
        print(f"Processed {building_id}")
    except Exception as e:
        print(f"Error saving {building_id}: {e}")
# Out:
# Processed 1001829067
# Processed 1001951858
# Skipping 1001829071: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1234761001
# Processed 1234761001
# Skipping 1001991633: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001664929
# Processed 1001664929
# Processed 1001829059
# Skipping 1001063639: heat_load_dis_walls.csv not found
# Skipping 1234761000: heat_load_dis_walls.csv not found
# Processed 1236594950
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001664925
# Processed 1001664925
# Skipping 1001906271: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1000238911
# Processed 1000238911
# Skipping 1001829057: heat_load_dis_walls.csv not found
# Skipping 1234760999: heat_load_dis_walls.csv not found
# Skipping 1002143357: heat_load_dis_walls.csv not found
# Skipping 1001951854: heat_load_dis_walls.csv not found
# Skipping 1001829069: heat_load_dis_walls.csv not found
# Skipping 1002313096: heat_load_dis_walls.csv not found
# Skipping 1002143351: heat_load_dis_walls.csv not found
# Processed 1001870854
# Skipping 1001870864: heat_load_dis_walls.csv not found
# Skipping 1002143293: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1002143352
# Processed 1002143352
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1002143353
# Processed 1002143353
# Skipping 1234647955: heat_load_dis_walls.csv not found
# Skipping 1002313093: heat_load_dis_walls.csv not found
# Skipping 1001991629: heat_load_dis_walls.csv not found
# Skipping 1001991628: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1000238920
# Processed 1000238920
# Processed 1001829085
# Processed 1001063646
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001829058
# Processed 1001829058
# Processed 1234806523
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001664941
# Processed 1001664941
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1236034494
# Processed 1236034494
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1000336709
# Processed 1000336709
# Skipping 1234761002: heat_load_dis_walls.csv not found
# Skipping 1002143355: heat_load_dis_walls.csv not found
# Skipping 1001906269: heat_load_dis_walls.csv not found
# Skipping 1001870855: heat_load_dis_walls.csv not found
# Processed 1001664944
# Skipping 1000336711: heat_load_dis_walls.csv not found
# Processed 1001829079
# Processed 1001870859
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001664928
# Processed 1001664928
# Skipping 1234806526: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001951889
# Processed 1001951889
# Processed 1001627558
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1235812262
# Processed 1235812262
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001627567
# Processed 1001627567
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001627542
# Processed 1001627542
# Processed 1001627549
# Skipping 1002143348: heat_load_dis_walls.csv not found
# Processed 1001951857
# Processed 1001063642
# Skipping 1000238921: heat_load_dis_walls.csv not found
# Processed 1001063637
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001664924
# Processed 1001664924
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001627541
# Processed 1001627541
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001627544
# Processed 1001627544
# Processed 1001627545
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001627547
# Processed 1001627547
# Skipping 1234761004: heat_load_dis_walls.csv not found
# Skipping 1000238925: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001627539
# Processed 1001627539
# Processed 1001951902
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001185939
# Processed 1001185939
# Skipping 1001664938: heat_load_dis_walls.csv not found
# Skipping 1001870878: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1002143354
# Processed 1002143354
# Skipping 1234761003: heat_load_dis_walls.csv not found
# Skipping 1001430744: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001829068
# Processed 1001829068
# Skipping 1001829063: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001664932
# Processed 1001664932
# Skipping 1001664937: heat_load_dis_walls.csv not found
# Skipping 1001664922: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001664939
# Processed 1001664939
# Skipping 1000238924: heat_load_dis_walls.csv not found
# Skipping 1002143291: heat_load_dis_walls.csv not found
# Skipping 1001627568: heat_load_dis_walls.csv not found
# Processed 1002389062
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001664930
# Processed 1001664930
# Skipping 1234760995: heat_load_dis_walls.csv not found
# Skipping 1235277376: heat_load_dis_walls.csv not found
# Processed 1001951898
# Processed 1001664942
# Processed 1001664940
# Processed 1002473722
# Skipping 1002539407: heat_load_dis_walls.csv not found
# Processed 1234647968
# Skipping 1000238923: heat_load_dis_walls.csv not found
# Skipping 1001951906: heat_load_dis_walls.csv not found
# Processed 1234982990
# Processed 1000238914
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001870882
# Processed 1001870882
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1235057414
# Processed 1235057414
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001870872
# Processed 1001870872
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001664935
# Processed 1001664935
# Processed 1000238907
# Processed 1001991627
# Processed 1234621926
# Processed 1002143349
# Processed 1001664934
# Processed 1234760996
# Skipping 1001951903: heat_load_dis_walls.csv not found
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001870876
# Processed 1001870876
# Processed 1002031280
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001829074
# Processed 1001829074
# Processed 1001829065
# Skipping 1001063643: heat_load_dis_walls.csv not found
# Processed 1001063635
# Skipping 1001829066: heat_load_dis_walls.csv not found
# Processed 1001829061
# Warning: Unknown SECOND_FUEL_CODE 'nan' for 1001627540
# Processed 1001627540
# Skipping 1001627570: heat_load_dis_walls.csv not found

# %%
# STEP 4: Summary check (optional)
# Description: Count how many heat_by_fuel.csv files were successfully created

count = 0

for _, row in epc_df.iterrows():
    building_id = str(row["BUILDING_REFERENCE_NUMBER"])
    output_file = os.path.join(models_base_path, building_id, "HEATING", "heat_by_fuel_walls.csv")
    
    if os.path.exists(output_file):
        count += 1

print(f"Total heat_by_fuel_walls.csv files created: {count}")
# Out:
# Total heat_by_fuel_walls.csv files created: 70
