# %%
# %%
# STEP 1: Setup — import libraries and define helper function

import subprocess
import os

def run(cmd):
    print(f"\n>>> {cmd}")
    subprocess.run(cmd, shell=True, executable="/bin/bash")

# %%
# %%
# STEP 2: Define root directory and simulator path

base_dir = "/Users/jakegehrung/Desktop/data_raw/baseline_models"
run_simulator_path = "/Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt"

print("Base directory:", base_dir)
# Out:
# Base directory: /Users/jakegehrung/Desktop/data_raw/baseline_models

# %%
# %%
# STEP 3: Load environment — ensure ESP-r tools are available

os.chdir(os.path.expanduser("~"))

run("source .profile")
run("which bps")  # check ESP-r simulator is available
# Out:
# >>> source .profile
#
# >>> which bps

# %%
# %%
# STEP 4: Discover all model directories — loop through buildings and valid model folders

valid_model_names = {
    "SemiDetached_2F_roof","Detached_2F_roof"
}

model_paths = []

for building in os.listdir(base_dir):
    building_path = os.path.join(base_dir, building)
    
    if not os.path.isdir(building_path):
        continue
    
    for sub in os.listdir(building_path):
        sub_path = os.path.join(building_path, sub)
        
        if sub in valid_model_names and os.path.isdir(sub_path):
            model_paths.append(sub_path)

print(f"Found {len(model_paths)} model(s)")
# Out:
# Found 69 model(s)

# %%
# %%
# STEP 5: Loop through each model — clean, run simulation, verify output

for model_root in model_paths:
    
    print("\n" + "="*60)
    print(f"Processing model: {model_root}")
    
    cfg_dir = os.path.join(model_root, "cfg")
    tmp_dir = os.path.join(model_root, "tmp")
    
    model_name = os.path.basename(model_root)
    cfg_file = f"SemiDetached_2F.cfg"
    
    print("CFG dir:", cfg_dir)
    print("TMP dir:", tmp_dir)
    
    # --- Clean tmp directory ---
    if os.path.exists(tmp_dir):
        os.chdir(tmp_dir)
        run("ls")
        
        files_to_remove = [
            "annual.res",
            f"{model_name}.res",
            "SemiDetached_2F.res",
            "AH_RESULTS.res"
        ]
        
        for f in files_to_remove:
            if os.path.exists(f):
                print(f"Removing {f}")
                os.remove(f)
            else:
                print(f"{f} not found (skipping)")
    else:
        print("WARNING: tmp directory not found, skipping model")
        continue
    
    # --- Run simulation ---
    if os.path.exists(cfg_dir):
        os.chdir(cfg_dir)
        run("ls")
        
        cmd = f"""
        source ~/.profile
        bps -mode script -file {cfg_file} < {run_simulator_path}
        """
        
        run(cmd)
    else:
        print("WARNING: cfg directory not found, skipping model")
        continue
    
    # --- Verify output ---
    os.chdir(tmp_dir)
    run("ls")
    
    if os.path.exists("annual.res"):
        print("Simulation successful: annual.res created")
    else:
        print("WARNING: annual.res not found — check simulation logs")
# Out:
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664924/SemiDetached_2F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664924/SemiDetached_2F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664924/SemiDetached_2F/tmp
#
# >>> ls
# annual.res
# Removing annual.res
# SemiDetached_2F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# annual.res
# espy
# fort.27
# fort.942
# graphic.err
# graphic.out
# heat_load_raw.csv
#
# >>>
#         source ~/.profile
#         bps -mode script -file SemiDetached_2F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
# (currently: SemiDetached_2F.cfg)
#
# Model configuration file?  The name (SemiDetached_2F.cfg) will be used.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: BLDres)
#
# Building results file name? (currently:  9  1)
# Simulation period
# Start day & month? (currently: 15  1)
# Simulation period
# End day & month? (currently: 2)
#
# Number of start-up days? (currently: 1)
#
# Building time-steps/hour?
# Hourly results integration? [Y]es [N]o ?
# Simulation control:
#   a results library
#   b simulation period            < delete last result set
#     ....................           ....................
#   * Save >> 2 (1+ surf temps)    g simulation options
#     ....................         i view simulation parameters
#   m monitor progress             o view save level 0 result
#   s commence simulation            ....................
#   t time-step control            ? help
#   - exit menu
#
#  Simulation control:?>  Use ../ctl/SemiDetached_2F.ctl
#  with the current model? [Y]es [N]o ?
#
#  Within the current model  2 control loops have been specified.
#  The overall project control is
# heating system control
#  and the zone control is
# zone controls
#
#
#  The sensor for loop  1 senses dry bulb temperature in flr0.
#  The actuator for function  1 is the air point in flr0.
# For building control  the following day types have been defined:
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  The sensor for loop  2 senses dry bulb temperature in flr1.
#  The actuator for function  2 is the air point in flr1.
# For building control  the following day types have been defined:
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#  zone ( 1) flr0         << control  1
#  zone ( 2) flr1         << control  2
#  zone ( 3) attic        << control  0
#
#  Within the current project 1 control loops have been specified.
#  plant control is
# heating system control
#
#  The sensor for loop  1 senses a mix of db T and MRT in flr0.
#
# FAILURE: in ../ctl/SemiDetached_2F.ctl:     0    0    0    0
#  the actuator 1st value (0) > allowable maximum -1!
#  The actuator for loop  1 is undefined actuation
#  For plant control
#  the following day types have been defined
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 dry bulb   > flow     period off
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 dry bulb   > flow     period off
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 dry bulb   > flux     period off
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 dry bulb   > flow     period off
# (currently: Results SemiDetached_2F)
#
# Result-set description?
# Continue with simulation? [Y]es [N]o ?
#
# Model configuration file: SemiDetached_2F.cfg
# Model description: Semi-Detached, 2-floor archetype
# Weather file: ../dbs/fintryclimate.epw
# Control file: ../ctl/SemiDetached_2F.ctl
# Building results file: ../tmp/annual.res
# Save option: 2 (Moderate)
# Prior warnings:      0
#
# Simulation period: 01-Jan  @ 01h00 to 31-Dec  @ 24h00
# Start-up period:      3 day(s).
# Building time steps: 30.00 minutes.
# Number of zones:      3.
# Building results file size:     24.1 Mbytes.
#
# Simulation commenced.
# CPU time:      0.5s.
#
# Save results? [Y]es [N]o ?
#
# Saved building result-set  1
#    for period day  1 month  1 to day 31 month 12
# Simulation control:
#   a results library
#   b simulation period            < delete last result set
#     ....................           ....................
#   * Save >> 2 (1+ surf temps)    g simulation options
#     ....................         i view simulation parameters
#   m monitor progress             o view save level 0 result
#   s commence simulation            ....................
#   t time-step control            ? help
#   - exit menu
#
#  Simulation control:?>
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
# >>> ls
# annual.res
# Simulation successful: annual.res created
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829085/SemiDetached_2F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829085/SemiDetached_2F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829085/SemiDetached_2F/tmp
#
# >>> ls
# annual.res
# Removing annual.res
# SemiDetached_2F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# annual.res
# espy
# fort.27
# fort.942
# graphic.err
# graphic.out
# heat_load_raw.csv
#
# >>>
#         source ~/.profile
#         bps -mode script -file SemiDetached_2F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
# (currently: SemiDetached_2F.cfg)
#
# Model configuration file?  The name (SemiDetached_2F.cfg) will be used.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: BLDres)
#
# Building results file name? (currently:  9  1)
# Simulation period
# Start day & month? (currently: 15  1)
# Simulation period
# End day & month? (currently: 2)
#
# Number of start-up days? (currently: 1)
#
# Building time-steps/hour?
# Hourly results integration? [Y]es [N]o ?
# Simulation control:
#   a results library
#   b simulation period            < delete last result set
#     ....................           ....................
#   * Save >> 2 (1+ surf temps)    g simulation options
#     ....................         i view simulation parameters
#   m monitor progress             o view save level 0 result
#   s commence simulation            ....................
#   t time-step control            ? help
#   - exit menu
#
#  Simulation control:?>  Use ../ctl/SemiDetached_2F.ctl
#  with the current model? [Y]es [N]o ?
#
#  Within the current model  2 control loops have been specified.
#  The overall project control is
# heating system control
#  and the zone control is
# zone controls
#
#
#  The sensor for loop  1 senses dry bulb temperature in flr0.
#  The actuator for function  1 is the air point in flr0.
# For building control  the following day types have been defined:
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  The sensor for loop  2 senses dry bulb temperature in flr1.
#  The actuator for function  2 is the air point in flr1.
# For building control  the following day types have been defined:
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#  zone ( 1) flr0         << control  1
#  zone ( 2) flr1         << control  2
#  zone ( 3) attic        << control  0
#
#  Within the current project 1 control loops have been specified.
#  plant control is
# heating system control
#
#  The sensor for loop  1 senses a mix of db T and MRT in flr0.
#
# FAILURE: in ../ctl/SemiDetached_2F.ctl:     0    0    0    0
#  the actuator 1st value (0) > allowable maximum -1!
#  The actuator for loop  1 is undefined actuation
#  For plant control
#  the following day types have been defined
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 dry bulb   > flow     period off
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 dry bulb   > flow     period off
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 dry bulb   > flux     period off
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 dry bulb   > flow     period off
# (currently: Results SemiDetached_2F)
#
# Result-set description?
# Continue with simulation? [Y]es [N]o ?
#
# Model configuration file: SemiDetached_2F.cfg
# Model description: Semi-Detached, 2-floor archetype
# Weather file: ../dbs/fintryclimate.epw
# Control file: ../ctl/SemiDetached_2F.ctl
# Building results file: ../tmp/annual.res
# Save option: 2 (Moderate)
# Prior warnings:      0
#
# Simulation period: 01-Jan  @ 01h00 to 31-Dec  @ 24h00
# Start-up period:      3 day(s).
# Building time steps: 30.00 minutes.
# Number of zones:      3.
# Building results file size:     24.1 Mbytes.
#
# Simulation commenced.
#     50% complete; expected finish time Sat Apr  4 14:15:15 2026
# CPU time:      0.5s.
#
# Save results? [Y]es [N]o ?
#
# Saved building result-set  1
#    for period day  1 month  1 to day 31 month 12
# Simulation control:
#   a results library
#   b simulation period            < delete last result set
#     ....................           ....................
#   * Save >> 2 (1+ surf temps)    g simulation options
#     ....................         i view simulation parameters
#   m monitor progress             o view save level 0 result
#   s commence simulation            ....................
#   t time-step control            ? help
#   - exit menu
#
#  Simulation control:?>
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
# >>> ls
# annual.res
# Simulation successful: annual.res created
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063639/Detached_2F_2
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063639/Detached_2F_2/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063639/Detached_2F_2/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_2F_2.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_2F_2.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_2F_2.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829071/EndTerrace_2F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829071/EndTerrace_2F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829071/EndTerrace_2F/tmp
#
# >>> ls
# annual.res not found (skipping)
# EndTerrace_2F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file EndTerrace_2F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: EndTerrace_2F.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234761002/Detached_2F_1
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234761002/Detached_2F_1/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234761002/Detached_2F_1/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_2F_1.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_2F_1.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_2F_1.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002539407/Detached_2F_1
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002539407/Detached_2F_1/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002539407/Detached_2F_1/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_2F_1.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_2F_1.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_2F_1.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063637/Detached_2F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063637/Detached_2F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063637/Detached_2F/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_2F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_2F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_2F.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664941/Detached_2F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664941/Detached_2F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664941/Detached_2F/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_2F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_2F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_2F.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001991633/Detached_1F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001991633/Detached_1F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001991633/Detached_1F/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_1F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_1F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_1F.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1235057414/Detached_2F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1235057414/Detached_2F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1235057414/Detached_2F/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_2F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_2F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_2F.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829079/SemiDetached_2F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829079/SemiDetached_2F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829079/SemiDetached_2F/tmp
#
# >>> ls
# annual.res
# Removing annual.res
# SemiDetached_2F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# annual.res
# espy
# fort.27
# fort.942
# graphic.err
# graphic.out
# heat_load_raw.csv
#
# >>>
#         source ~/.profile
#         bps -mode script -file SemiDetached_2F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
# (currently: SemiDetached_2F.cfg)
#
# Model configuration file?  The name (SemiDetached_2F.cfg) will be used.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: BLDres)
#
# Building results file name? (currently:  9  1)
# Simulation period
# Start day & month? (currently: 15  1)
# Simulation period
# End day & month? (currently: 2)
#
# Number of start-up days? (currently: 1)
#
# Building time-steps/hour?
# Hourly results integration? [Y]es [N]o ?
# Simulation control:
#   a results library
#   b simulation period            < delete last result set
#     ....................           ....................
#   * Save >> 2 (1+ surf temps)    g simulation options
#     ....................         i view simulation parameters
#   m monitor progress             o view save level 0 result
#   s commence simulation            ....................
#   t time-step control            ? help
#   - exit menu
#
#  Simulation control:?>  Use ../ctl/SemiDetached_2F.ctl
#  with the current model? [Y]es [N]o ?
#
#  Within the current model  2 control loops have been specified.
#  The overall project control is
# heating system control
#  and the zone control is
# zone controls
#
#
#  The sensor for loop  1 senses dry bulb temperature in flr0.
#  The actuator for function  1 is the air point in flr0.
# For building control  the following day types have been defined:
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  The sensor for loop  2 senses dry bulb temperature in flr1.
#  The actuator for function  2 is the air point in flr1.
# For building control  the following day types have been defined:
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#  zone ( 1) flr0         << control  1
#  zone ( 2) flr1         << control  2
#  zone ( 3) attic        << control  0
#
#  Within the current project 1 control loops have been specified.
#  plant control is
# heating system control
#
#  The sensor for loop  1 senses a mix of db T and MRT in flr0.
#
# FAILURE: in ../ctl/SemiDetached_2F.ctl:     0    0    0    0
#  the actuator 1st value (0) > allowable maximum -1!
#  The actuator for loop  1 is undefined actuation
#  For plant control
#  the following day types have been defined
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 dry bulb   > flow     period off
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 dry bulb   > flow     period off
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 dry bulb   > flux     period off
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 dry bulb   > flow     period off
# (currently: Results SemiDetached_2F)
#
# Result-set description?
# Continue with simulation? [Y]es [N]o ?
#      5% complete; expected finish time Sat Apr  4 14:15:43 2026
#
# Model configuration file: SemiDetached_2F.cfg
# Model description: Semi-Detached, 2-floor archetype
# Weather file: ../dbs/fintryclimate.epw
# Control file: ../ctl/SemiDetached_2F.ctl
# Building results file: ../tmp/annual.res
# Save option: 2 (Moderate)
# Prior warnings:      0
#
# Simulation period: 01-Jan  @ 01h00 to 31-Dec  @ 24h00
# Start-up period:      3 day(s).
# Building time steps: 30.00 minutes.
# Number of zones:      3.
# Building results file size:     24.1 Mbytes.
#
# Simulation commenced.
# CPU time:      0.5s.
#
# Save results? [Y]es [N]o ?
#
# Saved building result-set  1
#    for period day  1 month  1 to day 31 month 12
# Simulation control:
#   a results library
#   b simulation period            < delete last result set
#     ....................           ....................
#   * Save >> 2 (1+ surf temps)    g simulation options
#     ....................         i view simulation parameters
#   m monitor progress             o view save level 0 result
#   s commence simulation            ....................
#   t time-step control            ? help
#   - exit menu
#
#  Simulation control:?>
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
# >>> ls
# annual.res
# Simulation successful: annual.res created
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664922/EndTerrace_1F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664922/EndTerrace_1F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664922/EndTerrace_1F/tmp
#
# >>> ls
# annual.res not found (skipping)
# EndTerrace_1F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# ...
#
# Model configuration file?  The name (SemiDetached_2F.cfg) will be used.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: BLDres)
#
# Building results file name? (currently:  9  1)
# Simulation period
# Start day & month? (currently: 15  1)
# Simulation period
# End day & month? (currently: 2)
#
# Number of start-up days? (currently: 1)
#
# Building time-steps/hour?
# Hourly results integration? [Y]es [N]o ?
# Simulation control:
#   a results library
#   b simulation period            < delete last result set
#     ....................           ....................
#   * Save >> 2 (1+ surf temps)    g simulation options
#     ....................         i view simulation parameters
#   m monitor progress             o view save level 0 result
#   s commence simulation            ....................
#   t time-step control            ? help
#   - exit menu
#
#  Simulation control:?>  Use ../ctl/SemiDetached_2F.ctl
#  with the current model? [Y]es [N]o ?
#
#  Within the current model  2 control loops have been specified.
#  The overall project control is
# heating system control
#  and the zone control is
# zone controls
#
#
#  The sensor for loop  1 senses dry bulb temperature in flr0.
#  The actuator for function  1 is the air point in flr0.
# For building control  the following day types have been defined:
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  The sensor for loop  2 senses dry bulb temperature in flr1.
#  The actuator for function  2 is the air point in flr1.
# For building control  the following day types have been defined:
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 db temp   > flux      basic control: heating capacity 1000.0W. heating setpoint 20.00C.
#  zone ( 1) flr0         << control  1
#  zone ( 2) flr1         << control  2
#  zone ( 3) attic        << control  0
#
#  Within the current project 1 control loops have been specified.
#  plant control is
# heating system control
#
#  The sensor for loop  1 senses a mix of db T and MRT in flr0.
#
# FAILURE: in ../ctl/SemiDetached_2F.ctl:     0    0    0    0
#  the actuator 1st value (0) > allowable maximum -1!
#  The actuator for loop  1 is undefined actuation
#  For plant control
#  the following day types have been defined
# weekdays    saturday    sunday      holiday
#
#  Per|Start|Sensing  |Actuating  | weekdays control laws
#    1  0.00 dry bulb   > flow     period off
#
#  Per|Start|Sensing  |Actuating  | saturday control laws
#    1  0.00 dry bulb   > flow     period off
#
#  Per|Start|Sensing  |Actuating  | sunday control laws
#    1  0.00 dry bulb   > flux     period off
#
#  Per|Start|Sensing  |Actuating  | holiday control laws
#    1  0.00 dry bulb   > flow     period off
# (currently: Results SemiDetached_2F)
#
# Result-set description?
# Continue with simulation? [Y]es [N]o ?
#
# Model configuration file: SemiDetached_2F.cfg
# Model description: Semi-Detached, 2-floor archetype
# Weather file: ../dbs/fintryclimate.epw
# Control file: ../ctl/SemiDetached_2F.ctl
# Building results file: ../tmp/annual.res
# Save option: 2 (Moderate)
# Prior warnings:      0
#
# Simulation period: 01-Jan  @ 01h00 to 31-Dec  @ 24h00
# Start-up period:      3 day(s).
# Building time steps: 30.00 minutes.
# Number of zones:      3.
# Building results file size:     24.1 Mbytes.
#
# Simulation commenced.
# CPU time:      0.5s.
#
# Save results? [Y]es [N]o ?
#
# Saved building result-set  1
#    for period day  1 month  1 to day 31 month 12
# Simulation control:
#   a results library
#   b simulation period            < delete last result set
#     ....................           ....................
#   * Save >> 2 (1+ surf temps)    g simulation options
#     ....................         i view simulation parameters
#   m monitor progress             o view save level 0 result
#   s commence simulation            ....................
#   t time-step control            ? help
#   - exit menu
#
#  Simulation control:?>
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
# >>> ls
# annual.res
# Simulation successful: annual.res created
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234760999/Detached_2F_2
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234760999/Detached_2F_2/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234760999/Detached_2F_2/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_2F_2.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_2F_2.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_2F_2.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951857/Detached_2F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951857/Detached_2F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951857/Detached_2F/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_2F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_2F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_2F.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs
#
# ============================================================
# Processing model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063642/Detached_2F
# CFG dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063642/Detached_2F/cfg
# TMP dir: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063642/Detached_2F/tmp
#
# >>> ls
# annual.res not found (skipping)
# Detached_2F.res not found (skipping)
# SemiDetached_2F.res not found (skipping)
# AH_RESULTS.res not found (skipping)
#
# >>> ls
# SemiDetached_2F.cfg
# SemiDetached_2F.cnn
# fort.942
# graphic.err
# graphic.out
#
# >>>
#         source ~/.profile
#         bps -mode script -file Detached_2F.cfg < /Users/jakegehrung/Desktop/data_raw/ESP-r_automation_txt/run_simulator.txt
#
#
# Welcome to the Integrated simulator of ESP-r V13.3.17 of September 2023.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?>
#
#  Integrated simulator:?>  Warning:
# Configuration file not yet entered.
#
# Integrated simulator:
#   a define model                w warnings >> OFF
#   b assign weather file         r reporting >> silent
#     _________________________     _______________________
#   c initiate simulation         s H3K reports unavailable
#     _________________________     _________________________
#   t trace facilities            ? help
#   y multi-year sim >> OFF       - quit module
#
#  Integrated simulator:?> (currently: Detached_2F.cfg)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 1 1)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 31 12)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 3)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: 2)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: n)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: s)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: results)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: y)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  Warning: Model configuration file does not exist!
# Please retry.
# (currently: -)
#
# Model configuration file?  EASKF: EOF detected, error in input commands.
#
# >>> ls
# WARNING: annual.res not found — check simulation logs

# %%
# %%
# STEP 6: Copy results — move annual.res from tmp to cfg (overwrite if exists)

import shutil

for model_root in model_paths:
    
    print("\n" + "="*60)
    print(f"Copying results for model: {model_root}")
    
    cfg_dir = os.path.join(model_root, "cfg")
    tmp_dir = os.path.join(model_root, "tmp")
    
    src_file = os.path.join(tmp_dir, "annual.res")
    dst_file = os.path.join(cfg_dir, "annual.res")
    
    if not os.path.exists(src_file):
        print("WARNING: annual.res not found in tmp — skipping")
        continue
    
    if not os.path.exists(cfg_dir):
        print("WARNING: cfg directory not found — skipping")
        continue
    
    # Copy and overwrite if exists
    try:
        shutil.copy2(src_file, dst_file)
        print(f"Copied annual.res to {dst_file} (overwritten if existed)")
    except Exception as e:
        print(f"ERROR copying file: {e}")
# Out:
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664924/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664924/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829085/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829085/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063639/Detached_2F_2
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829071/EndTerrace_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234761002/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002539407/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063637/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664941/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001991633/Detached_1F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1235057414/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829079/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829079/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664922/EndTerrace_1F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234761003/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664925/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238907/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234761004/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002313096/Detached_2F_2
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001870878/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664940/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664940/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234982990/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1234982990/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234806523/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001870876/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001870882/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143357/Detached_2F_2
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951902/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234621926/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1234621926/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234647955/Detached_1F_2
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001906269/Detached_1F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951903/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627539/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143351/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627541/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1236594950/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627570/Detached_2F_4
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002031280/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627549/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627540/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627547/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001870854/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001870854/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001430744/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234760995/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1235812262/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000336709/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1000336709/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001991628/SemiDetached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664938/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238925/MidTerrace_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143291/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238914/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829063/SemiDetached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951854/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001870864/SemiDetached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001991629/SemiDetached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951898/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002473722/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063646/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063646/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001991627/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001870855/Detached_2F_3
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1236034494/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1236034494/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664930/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664930/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664937/EndTerrace_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829065/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829065/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238923/EndTerrace_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664939/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238924/MidTerrace_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234806526/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664942/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664942/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000336711/SemiDetached_1F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002313093/Detached_1F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234761001/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664929/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664929/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951889/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664944/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664944/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001870872/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664928/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664928/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063635/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002389062/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829074/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829074/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1235277376/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234761000/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627568/Detached_2F_4
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143354/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143353/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951906/Detached_2F_2
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627567/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234647968/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627558/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143352/Detached_1F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143355/Detached_1F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143348/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627542/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627545/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001906271/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001185939/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143349/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001627544/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238921/MidTerrace_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829069/MidTerrace_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664932/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829058/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829058/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829067/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829067/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664935/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664935/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951858/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234760996/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063643/EndTerrace_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001870859/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829059/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829059/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664934/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001664934/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829066/EndTerrace_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829061/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829061/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238911/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238911/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829068/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829068/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001829057/SemiDetached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1002143293/Detached_2F_1
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238920/SemiDetached_2F
# Copied annual.res to /Users/jakegehrung/Desktop/data_raw/baseline_models/1000238920/SemiDetached_2F/cfg/annual.res (overwritten if existed)
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1234760999/Detached_2F_2
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001951857/Detached_2F
# WARNING: annual.res not found in tmp — skipping
#
# ============================================================
# Copying results for model: /Users/jakegehrung/Desktop/data_raw/baseline_models/1001063642/Detached_2F
# WARNING: annual.res not found in tmp — skipping
